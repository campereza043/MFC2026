# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Parámetros (deben coincidir con los de Fortran)
a, b = -2, 2
N_steps = 769
m = 20
k = 0.0013

# 2. Funciones exactas para comparar
def u_exacta(x, t):
    return np.exp(1j * t) * np.sin(x)

# 3. Cargar datos del archivo .dat
# Usamos genfromtxt que maneja bien los espacios y comentarios (#)
data = np.loadtxt('resultados.dat')

# El archivo tiene: t, x, u_real, u_imag, u_abs
t_data = data[:, 0]
x_data = data[:, 1]
u_real_num = data[:, 2]
u_imag_num = data[:, 3]

# 4. Extraer el último paso de tiempo para la comparación
# Como pusimos una línea en blanco en Fortran, los datos están agrupados.
# Vamos a tomar los últimos 'm+1' puntos que corresponden a t_final.
x_final = x_data[-(m+1):]
u_real_final = u_real_num[-(m+1):]
u_imag_final = u_imag_num[-(m+1):]
t_final = t_data[-1]

# Calcular solución exacta en t_final
x_plot = np.linspace(a, b, 200)
u_ex = u_exacta(x_plot, t_final)

# 5. Graficar
plt.figure(figsize=(12, 5))

# Subplot Parte Real
plt.subplot(1, 2, 1)
plt.plot(x_plot, u_ex.real, 'r-', label='Exacta (Real)', alpha=0.7)
plt.scatter(x_final, u_real_final, color='black', marker='x', label='Numérica Fortran')
plt.title(f'Parte Real en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Re(u)')
plt.grid(False)
plt.legend()

# Subplot Parte Imaginaria
plt.subplot(1, 2, 2)
plt.plot(x_plot, u_ex.imag, 'b-', label='Exacta (Imag)', alpha=0.7)
plt.scatter(x_final, u_imag_final, color='black', marker='x', label='Numérica Fortran')
plt.title(f'Parte Imaginaria en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Im(u)')

plt.legend()

plt.tight_layout()
plt.show()

# 6. Imprimir error en el notebook
u_ex_puntos = u_exacta(x_final, t_final)
error = np.abs((u_real_final + 1j*u_imag_final) - u_ex_puntos)
print(f"Error máximo en t_final: {np.max(error):.2e}")
# Out:
# Error máximo en t_final: 2.92e-03

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Parámetros (deben coincidir con los de Fortran)
a, b = -2, 2
N_steps = 769
m = 50
k = 0.0013

# 2. Funciones exactas para comparar
def u_exacta(x, t):
    return np.exp(1j * t) * np.sin(x)

# 3. Cargar datos del archivo .dat
# Usamos genfromtxt que maneja bien los espacios y comentarios (#)
data = np.loadtxt('resultados.dat')

# El archivo tiene: t, x, u_real, u_imag, u_abs
t_data = data[:, 0]
x_data = data[:, 1]
u_real_num = data[:, 2]
u_imag_num = data[:, 3]

# 4. Extraer el último paso de tiempo para la comparación
# Como pusimos una línea en blanco en Fortran, los datos están agrupados.
# Vamos a tomar los últimos 'm+1' puntos que corresponden a t_final.
x_final = x_data[-(m+1):]
u_real_final = u_real_num[-(m+1):]
u_imag_final = u_imag_num[-(m+1):]
t_final = t_data[-1]

# Calcular solución exacta en t_final
x_plot = np.linspace(a, b, 200)
u_ex = u_exacta(x_plot, t_final)

# 5. Graficar
plt.figure(figsize=(12, 5))

# Subplot Parte Real
plt.subplot(1, 2, 1)
plt.plot(x_plot, u_ex.real, 'r-', label='Exacta (Real)', alpha=0.7)
plt.scatter(x_final, u_real_final, color='black', marker='x', label='Numérica Fortran')
plt.title(f'Parte Real en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Re(u)')
plt.grid(False)
plt.legend()

# Subplot Parte Imaginaria
plt.subplot(1, 2, 2)
plt.plot(x_plot, u_ex.imag, 'b-', label='Exacta (Imag)', alpha=0.7)
plt.scatter(x_final, u_imag_final, color='black', marker='x', label='Numérica Fortran')
plt.title(f'Parte Imaginaria en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Im(u)')

plt.legend()

plt.tight_layout()
plt.show()

# 6. Imprimir error en el notebook
u_ex_puntos = u_exacta(x_final, t_final)
error = np.abs((u_real_final + 1j*u_imag_final) - u_ex_puntos)
print(f"Error máximo en t_final: {np.max(error):.2e}")
# Out:
# Error máximo en t_final: 4.72e-04

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Parámetros (deben coincidir con los de Fortran)
a, b = -2, 2
N_steps = 769
m = 20
k = 0.0013

# 2. Funciones exactas para comparar
def u_exacta(x, t):
    return np.exp(1j * t) * np.sin(x)

# 3. Cargar datos del archivo .dat
# Usamos genfromtxt que maneja bien los espacios y comentarios (#)
data = np.loadtxt('resultados.dat')

# El archivo tiene: t, x, u_real, u_imag, u_abs
t_data = data[:, 0]
x_data = data[:, 1]
u_real_num = data[:, 2]
u_imag_num = data[:, 3]

# 4. Extraer el último paso de tiempo para la comparación
# Como pusimos una línea en blanco en Fortran, los datos están agrupados.
# Vamos a tomar los últimos 'm+1' puntos que corresponden a t_final.
x_final = x_data[-(m+1):]
u_real_final = u_real_num[-(m+1):]
u_imag_final = u_imag_num[-(m+1):]
t_final = t_data[-1]

# Calcular solución exacta en t_final
x_plot = np.linspace(a, b, 200)
u_ex = u_exacta(x_plot, t_final)

# 5. Graficar
plt.figure(figsize=(12, 5))

# Subplot Parte Real
plt.subplot(1, 2, 1)
plt.plot(x_plot, u_ex.real, 'r-', label='Exacta (Real)', alpha=0.7)
plt.scatter(x_final, u_real_final, color='black', marker='x', label='Numérica Fortran')
plt.title(f'Parte Real en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Re(u)')
plt.grid(False)
plt.legend()

# Subplot Parte Imaginaria
plt.subplot(1, 2, 2)
plt.plot(x_plot, u_ex.imag, 'b-', label='Exacta (Imag)', alpha=0.7)
plt.scatter(x_final, u_imag_final, color='black', marker='x', label='Numérica Fortran')
plt.title(f'Parte Imaginaria en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Im(u)')

plt.legend()

plt.tight_layout()
plt.show()

# 6. Imprimir error en el notebook
u_ex_puntos = u_exacta(x_final, t_final)
error = np.abs((u_real_final + 1j*u_imag_final) - u_ex_puntos)
print(f"Error máximo en t_final: {np.max(error):.2e}")
# Out:
# Error máximo en t_final: 2.92e-03

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Cargar el dataset generado por Fortran
# Asegúrate de que el nombre coincida con tu archivo .dat
data = np.loadtxt('resultados.dat')

# Estructura del archivo: t (col 0), x (col 1), u_real (col 2), u_imag (col 3)
t_data = data[:, 0]
x_data = data[:, 1]
u_real = data[:, 2]
u_imag = data[:, 3]

# 2. Definir los tiempos específicos que quieres visualizar
tiempos_objetivo = [0.250900, 0.500500, 0.750100, 0.999700]

# Configuración de la gráfica (2 subplots: Real e Imaginario)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
colors = ['#1f77b4', '#d62728', '#2ca02c', '#9467bd'] # Azul, Rojo, Verde, Púrpura
markers = ['o', 's', '^', 'd']

for i, t_obj in enumerate(tiempos_objetivo):
    # Buscamos el tiempo en el dataset que más se aproxime al objetivo
    idx_t = np.unique(t_data)[np.abs(np.unique(t_data) - t_obj).argmin()]
    
    # Filtramos los datos para ese tiempo exacto encontrado
    mask = (t_data == idx_t)
    x_plot = x_data[mask]
    re_plot = u_real[mask]
    im_plot = u_imag[mask]
    
    label_str = f't = {idx_t:.4f}'
    
    # Graficar Parte Real
    ax1.plot(x_plot, re_plot, label=label_str, color=colors[i], 
             marker=markers[i], markersize=5, linestyle='-', linewidth=1)
    
    # Graficar Parte Imaginaria
    ax2.plot(x_plot, im_plot, label=label_str, color=colors[i], 
             marker=markers[i], markersize=5, linestyle='-', linewidth=1)

# --- Estética del gráfico Real ---
ax1.set_title('Parte Real $Re(u)$')
ax1.set_xlabel('Posición $x$')
ax1.set_ylabel('$Re(u)$')
ax1.grid(True, linestyle='--', alpha=0.6)
ax1.legend()

# --- Estética del gráfico Imaginario ---
ax2.set_title('Parte Imaginaria $Im(u)$')
ax2.set_xlabel('Posición $x$')
ax2.set_ylabel('$Im(u)$')
ax2.grid(True, linestyle='--', alpha=0.6)
ax2.legend()

plt.suptitle(f'Evolución de la Función de Onda (Malla M=20)', fontsize=14)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Cargar el dataset generado por Fortran
# Asegúrate de que 'resultados.dat' esté en la misma carpeta
data = np.loadtxt('resultados_2.dat')

t_data = data[:, 0]
x_data = data[:, 1]
u_real_num = data[:, 2] # Datos numéricos de Fortran
u_imag_num = data[:, 3]

# 2. Tiempos específicos solicitados
tiempos_objetivo = [0.250900, 0.500500, 0.750100, 0.999700]

# Configuración de la gráfica (2 subplots: Real e Imaginario)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
colors = ['#1f77b4', '#d62728', '#2ca02c', '#9467bd'] 
markers = ['o', 's', '^', 'd']

for i, t_obj in enumerate(tiempos_objetivo):
    # Buscamos el tiempo en el dataset más cercano al objetivo
    tiempos_unicos = np.unique(t_data)
    idx_t = tiempos_unicos[np.abs(tiempos_unicos - t_obj).argmin()]
    
    # Filtramos los datos numéricos para ese tiempo
    mask = (t_data == idx_t)
    x_plot = x_data[mask]
    re_num = u_real_num[mask]
    im_num = u_imag_num[mask]
    
    # --- Cálculo de la Solución Exacta ---
    # u(x,t) = cos(t)cos(x) + i*sin(t)cos(x)
    x_exact = np.linspace(-np.pi, np.pi, 200) # Malla fina para la curva suave
    re_exact = np.cos(idx_t) * np.cos(x_exact)
    im_exact = np.sin(idx_t) * np.cos(x_exact)
    
    label_str = f't ≈ {idx_t:.4f}'
    
    # --- Graficar Parte Real ---
    # Puntos: Simulación Fortran | Línea: Solución Exacta
    ax1.plot(x_plot, re_num, color=colors[i], marker=markers[i], 
             linestyle='', markersize=5, label=f'Num {label_str}')
    ax1.plot(x_exact, re_exact, color=colors[i], linestyle='-', alpha=0.5)
    
    # --- Graficar Parte Imaginaria ---
    ax2.plot(x_plot, im_num, color=colors[i], marker=markers[i], 
             linestyle='', markersize=5, label=f'Num {label_str}')
    ax2.plot(x_exact, im_exact, color=colors[i], linestyle='-', alpha=0.5)

# --- Estética del gráfico Real ---
ax1.set_title('Parte Real $Re(u)$')
ax1.set_xlabel('Posición $x$')
ax1.set_ylabel('$Re(u)$')
ax1.set_xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
ax1.set_xticklabels([r'$-\pi$', r'$-\pi/2$', '0', r'$\pi/2$', r'$\pi$'])
ax1.grid(True, linestyle='--', alpha=0.6)
ax1.legend(fontsize='small')

# --- Estética del gráfico Imaginario ---
ax2.set_title('Parte Imaginaria $Im(u)$')
ax2.set_xlabel('Posición $x$')
ax2.set_ylabel('$Im(u)$')
ax2.set_xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
ax2.set_xticklabels([r'$-\pi$', r'$-\pi/2$', '0', r'$\pi/2$', r'$\pi$'])
ax2.grid(True, linestyle='--', alpha=0.6)
ax2.legend(fontsize='small')

plt.suptitle(r'Comparación Simulación vs Solución Exacta $u(x,t) = e^{it}\cos(x)$', fontsize=14)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Cargar el dataset (asegúrate de que el archivo existe)
data = np.loadtxt('resultados_prob3.dat', comments='#')

# 2. Ordenar datos por tiempo y posición
# Esto evita líneas cruzadas y errores de visualización
data = data[np.lexsort((data[:, 1], data[:, 0]))]

t_data = data[:, 0]
x_data = data[:, 1]
u_real = data[:, 2] 
u_imag = data[:, 3]

# 3. Tiempos objetivos
tiempos_objetivo = [0.250900, 0.500500, 0.750100, 0.999700]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

for t_obj in tiempos_objetivo:
    # Seleccionar el tiempo más cercano en los datos reales
    idx = (np.abs(t_data - t_obj)).argmin()
    t_val = t_data[idx]
    
    # Filtrar datos para este tiempo exacto
    mask = np.isclose(t_data, t_val, atol=1e-5)
    
    # Graficar puntos numéricos (sin líneas de tendencia, solo los datos)
    ax1.plot(x_data[mask], u_real[mask], 'o', markersize=4, label=f't={t_val:.4f}')
    ax2.plot(x_data[mask], u_imag[mask], 's', markersize=4, label=f't={t_val:.4f}')

# Estética de las gráficas
ax1.set_title('Parte Real (Resultados Numéricos)')
ax1.set_xlabel('x')
ax1.set_ylabel('Re(u)')
ax1.grid(True)
ax1.legend()

ax2.set_title('Parte Imaginaria (Resultados Numéricos)')
ax2.set_xlabel('x')
ax2.set_ylabel('Im(u)')
ax2.grid(True)
ax2.legend()

plt.suptitle('Salida cruda del algoritmo de Crank-Nicolson', fontsize=14)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Cargar el dataset generado por Fortran (Actualizado al nuevo archivo)
# Asegúrate de que 'resultados_prob3.dat' esté en la misma carpeta
data = np.loadtxt('resultados_prob3.dat')

t_data = data[:, 0]
x_data = data[:, 1]
u_real_num = data[:, 2] # Datos numéricos de Fortran
u_imag_num = data[:, 3]

# 2. Tiempos específicos solicitados
tiempos_objetivo = [0.250900, 0.500500, 0.750100, 0.999700]

# Configuración de la gráfica (2 subplots: Real e Imaginario)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
colors = ['#1f77b4', '#d62728', '#2ca02c', '#9467bd'] 
markers = ['o', 's', '^', 'd']

for i, t_obj in enumerate(tiempos_objetivo):
    # Buscamos el tiempo en el dataset más cercano al objetivo
    tiempos_unicos = np.unique(t_data)
    idx_t = tiempos_unicos[np.abs(tiempos_unicos - t_obj).argmin()]
    
    # Filtramos los datos numéricos para ese tiempo
    mask = (t_data == idx_t)
    x_plot = x_data[mask]
    re_num = u_real_num[mask]
    im_num = u_imag_num[mask]
    
    # --- Cálculo de la Solución Exacta ---
    # u(x,t) = exp(i*(t+x)) = cos(t+x) + i*sin(t+x)
    # NUEVO DOMINIO: de 0 a pi
    x_exact = np.linspace(0, np.pi, 200) # Malla fina para la curva suave
    re_exact = np.cos(idx_t + x_exact)
    im_exact = np.sin(idx_t + x_exact)
    
    label_str = f't ≈ {idx_t:.4f}'
    
    # --- Graficar Parte Real ---
    # Puntos: Simulación Fortran | Línea: Solución Exacta
    ax1.plot(x_plot, re_num, color=colors[i], marker=markers[i], 
             linestyle='', markersize=5, label=f'Num {label_str}')
    ax1.plot(x_exact, re_exact, color=colors[i], linestyle='-', alpha=0.5)
    
    # --- Graficar Parte Imaginaria ---
    ax2.plot(x_plot, im_num, color=colors[i], marker=markers[i], 
             linestyle='', markersize=5, label=f'Num {label_str}')
    ax2.plot(x_exact, im_exact, color=colors[i], linestyle='-', alpha=0.5)

# --- Estética del gráfico Real ---
ax1.set_title('Parte Real $Re(u)$')
ax1.set_xlabel('Posición $x$')
ax1.set_ylabel('$Re(u)$')
# NUEVOS LÍMITES EN X
ax1.set_xticks([0, np.pi/4, np.pi/2, 3*np.pi/4, np.pi])
ax1.set_xticklabels(['0', r'$\pi/4$', r'$\pi/2$', r'$3\pi/4$', r'$\pi$'])
ax1.grid(True, linestyle='--', alpha=0.6)
ax1.legend(fontsize='small')

# --- Estética del gráfico Imaginario ---
ax2.set_title('Parte Imaginaria $Im(u)$')
ax2.set_xlabel('Posición $x$')
ax2.set_ylabel('$Im(u)$')
# NUEVOS LÍMITES EN X
ax2.set_xticks([0, np.pi/4, np.pi/2, 3*np.pi/4, np.pi])
ax2.set_xticklabels(['0', r'$\pi/4$', r'$\pi/2$', r'$3\pi/4$', r'$\pi$'])
ax2.grid(True, linestyle='--', alpha=0.6)
ax2.legend(fontsize='small')

# TÍTULO ACTUALIZADO
plt.suptitle(r'Comparación Simulación vs Solución Exacta $u(x,t) = e^{i(t+x)}$', fontsize=14)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('resultados_prob3.dat')
t_data, x_data, re_num, im_num = data[:, 0], data[:, 1], data[:, 2], data[:, 3]

tiempos = np.unique(t_data)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

for t_val in tiempos:
    m = (t_data == t_val)
    # Solución Exacta: u(x,t) = x * exp(i*(x+t))
    # Re = x * cos(x+t), Im = x * sin(x+t)
    x_ex = np.linspace(0, np.pi, 200)
    re_ex = x_ex * np.cos(x_ex + t_val)
    im_ex = x_ex * np.sin(x_ex + t_val)
    
    label = f't = {t_val:.2f}'
    ax1.plot(x_data[m], re_num[m], 'o', label=f'Num {label}')
    ax1.plot(x_ex, re_ex, '--', alpha=0.6)
    
    ax2.plot(x_data[m], im_num[m], 's', label=f'Num {label}')
    ax2.plot(x_ex, im_ex, '--', alpha=0.6)

ax1.set_title('Parte Real (Anulada en $x=0$, Libre en $x=\pi$)')
ax2.set_title('Parte Imaginaria (Anulada en $x=0$, Libre en $x=\pi$)')
for ax in [ax1, ax2]:
    ax.set_xlabel('x-axis')
    ax.legend()
    ax.grid(True)

plt.suptitle('Replicando Figura 5 del Paper (Test Problem 3)')
plt.show()
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\p'
# <>:26: SyntaxWarning: invalid escape sequence '\p'
# <>:25: SyntaxWarning: invalid escape sequence '\p'
# <>:26: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_4187/1974610293.py:25: SyntaxWarning: invalid escape sequence '\p'
#   ax1.set_title('Parte Real (Anulada en $x=0$, Libre en $x=\pi$)')
# /tmp/ipykernel_4187/1974610293.py:26: SyntaxWarning: invalid escape sequence '\p'
#   ax2.set_title('Parte Imaginaria (Anulada en $x=0$, Libre en $x=\pi$)')

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Cargar el dataset generado por Fortran
# Asegúrate de que 'resultados_prob3.dat' esté en la misma carpeta
data = np.loadtxt('resultados_prob3.dat')

t_data = data[:, 0]
x_data = data[:, 1]
u_real_num = data[:, 2] 
u_imag_num = data[:, 3]

# 2. Tiempos específicos solicitados
tiempos_objetivo = [0.250900, 0.500500, 0.750100, 0.999700]

# Configuración de la gráfica (2 subplots: Real e Imaginario)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
colors = ['#1f77b4', '#d62728', '#2ca02c', '#9467bd'] 
markers = ['o', 's', '^', 'd']

for i, t_obj in enumerate(tiempos_objetivo):
    # Buscamos el tiempo en el dataset más cercano al objetivo
    tiempos_unicos = np.unique(t_data)
    idx_t = tiempos_unicos[np.abs(tiempos_unicos - t_obj).argmin()]
    
    # Filtramos los datos numéricos para ese tiempo
    mask = (t_data == idx_t)
    x_plot = x_data[mask]
    re_num = u_real_num[mask]
    im_num = u_imag_num[mask]
    
    # --- Cálculo de la Solución Exacta ---
    # u(x,t) = e^{it+x} = exp(x)*cos(t) + i*exp(x)*sin(t)
    x_exact = np.linspace(0, np.pi, 200) # Malla en [0, pi]
    re_exact = np.exp(x_exact) * np.cos(idx_t)
    im_exact = np.exp(x_exact) * np.sin(idx_t)
    
    label_str = f't ≈ {idx_t:.4f}'
    
    # --- Graficar Parte Real ---
    ax1.plot(x_plot, re_num, color=colors[i], marker=markers[i], 
             linestyle='', markersize=5, label=f'Num {label_str}')
    ax1.plot(x_exact, re_exact, color=colors[i], linestyle='-', alpha=0.5)
    
    # --- Graficar Parte Imaginaria ---
    ax2.plot(x_plot, im_num, color=colors[i], marker=markers[i], 
             linestyle='', markersize=5, label=f'Num {label_str}')
    ax2.plot(x_exact, im_exact, color=colors[i], linestyle='-', alpha=0.5)

# --- Estética del gráfico Real ---
ax1.set_title('Parte Real $Re(u) = e^x \cos(t)$')
ax1.set_xlabel('Posición $x$')
ax1.set_ylabel('$Re(u)$')
ax1.set_xticks([0, np.pi/4, np.pi/2, 3*np.pi/4, np.pi])
ax1.set_xticklabels(['0', r'$\pi/4$', r'$\pi/2$', r'$3\pi/4$', r'$\pi$'])
ax1.grid(True, linestyle='--', alpha=0.6)
ax1.legend(fontsize='small')

# --- Estética del gráfico Imaginario ---
ax2.set_title('Parte Imaginaria $Im(u) = e^x \sin(t)$')
ax2.set_xlabel('Posición $x$')
ax2.set_ylabel('$Im(u)$')
ax2.set_xticks([0, np.pi/4, np.pi/2, 3*np.pi/4, np.pi])
ax2.set_xticklabels(['0', r'$\pi/4$', r'$\pi/2$', r'$3\pi/4$', r'$\pi$'])
ax2.grid(True, linestyle='--', alpha=0.6)
ax2.legend(fontsize='small')

plt.suptitle(r'Comparación Simulación vs Solución Exacta $u(x,t) = e^{it+x}$', fontsize=14)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# <>:51: SyntaxWarning: invalid escape sequence '\c'
# <>:60: SyntaxWarning: invalid escape sequence '\s'
# <>:51: SyntaxWarning: invalid escape sequence '\c'
# <>:60: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_4187/4113644998.py:51: SyntaxWarning: invalid escape sequence '\c'
#   ax1.set_title('Parte Real $Re(u) = e^x \cos(t)$')
# /tmp/ipykernel_4187/4113644998.py:60: SyntaxWarning: invalid escape sequence '\s'
#   ax2.set_title('Parte Imaginaria $Im(u) = e^x \sin(t)$')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Cargar datos: t, x, u_real, u_imag, analitica_real, analitica_imag
data = np.loadtxt('resultados_analisis.dat')
# Filtrar para el último tiempo
last_t = data[data[:, 0] == data[-1, 0]]

x = last_t[:, 1]
u_imag = last_t[:, 3]
ana_imag = last_t[:, 5]

plt.figure(figsize=(10, 5))
plt.plot(x, u_imag, 'r--', label='Tu Parte Imaginaria')
plt.plot(x, ana_imag, 'b-', label='Analítica (Exacta)')
plt.title('Comparación de Fase: Tu código vs Teoría')
plt.xlabel('x')
plt.ylabel('Imaginario')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Cargamos el archivo, ignorando la línea de comentario de cabecera
data = np.loadtxt('resultados_prob3.dat', comments='#')

# Filtramos para obtener solo el último paso de tiempo (t_final)
t_final = data[data[:, 0] == data[-1, 0]]

x = t_final[:, 1]
u_sum = t_final[:, 5]  # Esta es nuestra nueva columna 6 (índice 5)

plt.figure(figsize=(10, 6))
plt.plot(x, u_sum, 'm-o', label='Suma (Real + Imag)')
plt.title('Suma de componentes en t_final')
plt.xlabel('x')
plt.ylabel('u_real + u_imag')
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Parámetros (deben coincidir con los de Fortran)
a, b = -2.0, 2.0
N_steps = 769
m = 20
k = 0.0013

# 2. Función exacta para comparar (SINH)
def u_exacta(x, t):
    return np.exp(1j * t) * np.sinh(x)

# 3. Cargar datos del archivo .dat
data = np.loadtxt('resultadosrampa.dat')

t_data = data[:, 0]
x_data = data[:, 1]
u_real_num = data[:, 2]
u_imag_num = data[:, 3]

# 4. Extraer el último paso de tiempo (t_final)
x_final = x_data[-(m+1):]
u_real_final = u_real_num[-(m+1):]
u_imag_final = u_imag_num[-(m+1):]
t_final = t_data[-1]

# Solución exacta para curva continua
x_plot = np.linspace(a, b, 200)
u_ex = u_exacta(x_plot, t_final)

# 5. Graficar
plt.figure(figsize=(14, 5))

# Subplot Parte Real (Izquierda)
plt.subplot(1, 2, 1)
plt.plot(x_plot, u_ex.real, 'r-', label='Exacta (Real)', alpha=0.7)
plt.scatter(x_final, u_real_final, color='black', marker='x', label='Numérica Fortran')
plt.title(f'Parte Real en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Re(u)')
plt.grid(True, linestyle='--')
plt.legend()

# Subplot Parte Imaginaria (Derecha)
plt.subplot(1, 2, 2)
plt.plot(x_plot, u_ex.imag, 'b-', label='Exacta (Imag)', alpha=0.7)
plt.scatter(x_final, u_imag_final, color='black', marker='x', label='Numérica Fortran')
plt.title(f'Parte Imaginaria en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Im(u)')
plt.grid(True, linestyle='--')
plt.legend()

plt.tight_layout()
plt.show()

# 6. Error
u_ex_puntos = u_exacta(x_final, t_final)
error = np.abs((u_real_final + 1j*u_imag_final) - u_ex_puntos)
print(f"Error máximo en t_final: {np.max(error):.2e}")
# Out:
# Error máximo en t_final: 3.00e+00

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Parámetros (deben coincidir con el Fortran actualizado)
a, b = 0.0, np.pi
N_steps = 769
m = 20
k = 0.0013

# 2. Función exacta para comparar: exp(i*(x + t))
def u_exacta(x, t):
    return np.exp(1j * (x + t))

# 3. Cargar datos del archivo .dat
# loadtxt manejará el archivo generado por Fortran ignorando líneas en blanco
try:
    data = np.loadtxt('resultadosrampa.dat')
except Exception as e:
    print(f"Error al cargar el archivo: {e}")
    data = np.array([])

if data.size > 0:
    t_data = data[:, 0]
    x_data = data[:, 1]
    u_real_num = data[:, 2]
    u_imag_num = data[:, 3]

    # 4. Extraer el último paso de tiempo para la comparación
    # Tomamos los últimos 'm+1' puntos que corresponden a t_final
    x_final = x_data[-(m+1):]
    u_real_final = u_real_num[-(m+1):]
    u_imag_final = u_imag_num[-(m+1):]
    t_final = t_data[-1]

    # Calcular solución exacta en t_final para la curva continua
    x_plot = np.linspace(a, b, 200)
    u_ex = u_exacta(x_plot, t_final)

    # 5. Graficar
    plt.figure(figsize=(14, 5))

    # Subplot Parte Real (Izquierda)
    plt.subplot(1, 2, 1)
    plt.plot(x_plot, u_ex.real, 'r-', label='Exacta (Real)', alpha=0.7)
    plt.scatter(x_final, u_real_final, color='black', marker='x', label='Numérica Fortran')
    plt.title(f'Parte Real en t = {t_final:.4f}')
    plt.xlabel('x')
    plt.ylabel('Re(u)')
    plt.grid(True, linestyle='--')
    plt.legend()

    # Subplot Parte Imaginaria (Derecha)
    plt.subplot(1, 2, 2)
    plt.plot(x_plot, u_ex.imag, 'b-', label='Exacta (Imag)', alpha=0.7)
    plt.scatter(x_final, u_imag_final, color='black', marker='x', label='Numérica Fortran')
    plt.title(f'Parte Imaginaria en t = {t_final:.4f}')
    plt.xlabel('x')
    plt.ylabel('Im(u)')
    plt.grid(True, linestyle='--')
    plt.legend()

    plt.tight_layout()
    plt.show()

    # 6. Cálculo de Error
    u_ex_puntos = u_exacta(x_final, t_final)
    error = np.abs((u_real_final + 1j*u_imag_final) - u_ex_puntos)
    print(f"Error máximo en t_final: {np.max(error):.2e}")
else:
    print("No hay datos para graficar. Asegúrate de correr primero el programa Fortran.")
# Out:
# Error máximo en t_final: 2.73e-03

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Parámetros (deben coincidir con el Fortran: m=100)
a, b = 0.0, np.pi
m = 1000
# El archivo guarda m+1 puntos por cada paso de tiempo
# Ajustamos los parámetros de carga
N_steps = 1000

# 2. Función exacta: exp(x + it)
def u_exacta(x, t):
    return np.exp(x + 1j * t)

# 3. Cargar datos
# Usamos genfromtxt ya que el archivo tiene líneas en blanco
data = np.genfromtxt('resultadosrampa.dat')

# Extraer el último paso de tiempo (t_final)
# Buscamos los últimos (m+1) datos
t_final = data[- (m + 1):, 0][0]
x_final = data[- (m + 1):, 1]
u_real_final = data[- (m + 1):, 2]
u_imag_final = data[- (m + 1):, 3]

# 4. Solución exacta para la línea continua
x_plot = np.linspace(a, b, 200)
u_ex = u_exacta(x_plot, t_final)

# 5. Graficar
plt.figure(figsize=(14, 5))

# Subplot Real
plt.subplot(1, 2, 1)
plt.plot(x_plot, u_ex.real, 'r-', label='Exacta: $e^x \cos(t)$', alpha=0.6)
plt.scatter(x_final, u_real_final, color='black', marker='.', s=10, label='Numérica')
plt.title(f'Parte Real en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Re(u)')
plt.legend()
plt.grid(True, linestyle=':')

# Subplot Imaginaria
plt.subplot(1, 2, 2)
plt.plot(x_plot, u_ex.imag, 'b-', label='Exacta: $e^x \sin(t)$', alpha=0.6)
plt.scatter(x_final, u_imag_final, color='black', marker='.', s=10, label='Numérica')
plt.title(f'Parte Imaginaria en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Im(u)')
plt.legend()
plt.grid(True, linestyle=':')

plt.tight_layout()
plt.show()

# 6. Reporte de Error
u_ex_puntos = u_exacta(x_final, t_final)
error = np.abs((u_real_final + 1j * u_imag_final) - u_ex_puntos)
print(f"Error máximo absoluto en t_final: {np.max(error):.4e}")
# Out:
# <>:35: SyntaxWarning: invalid escape sequence '\c'
# <>:45: SyntaxWarning: invalid escape sequence '\s'
# <>:35: SyntaxWarning: invalid escape sequence '\c'
# <>:45: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_4841/4203961310.py:35: SyntaxWarning: invalid escape sequence '\c'
#   plt.plot(x_plot, u_ex.real, 'r-', label='Exacta: $e^x \cos(t)$', alpha=0.6)
# /tmp/ipykernel_4841/4203961310.py:45: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x_plot, u_ex.imag, 'b-', label='Exacta: $e^x \sin(t)$', alpha=0.6)
# Error máximo absoluto en t_final: 3.1830e+00

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Parámetros (Asegúrate de que coincidan con Fortran: m=100, N=1000)
a, b = 0.0, np.pi
m = 100
N_steps = 1000
k = 0.0001
t_final_teorico = N_steps * k

# 2. Función exacta: e^x * (cos(t) + i*sin(t))
def u_exacta(x, t):
    # Usamos la forma expandida para coincidir con el Fortran
    return np.exp(x) * (np.cos(t) + 1j * np.sin(t))

# 3. Cargar datos
data = np.genfromtxt('resultadosrampa.dat')

# Extraer el último paso de tiempo
# Tomamos los últimos (m+1) puntos
x_final = data[- (m + 1):, 1]
u_real_num = data[- (m + 1):, 2]
u_imag_num = data[- (m + 1):, 3]

# 4. Solución exacta
x_plot = np.linspace(a, b, 200)
u_ex = u_exacta(x_plot, t_final_teorico)

# 5. Graficar
plt.figure(figsize=(14, 5))

# Subplot Real
plt.subplot(1, 2, 1)
plt.plot(x_plot, u_ex.real, 'r-', label='Exacta: $e^x \cos(t)$', alpha=0.6)
plt.scatter(x_final, u_real_num, color='black', marker='.', s=10, label='Numérica')
plt.title(f'Parte Real en t ≈ {t_final_teorico:.4f}')
plt.xlabel('x')
plt.ylabel('Re(u)')
plt.legend()
plt.grid(True, linestyle=':')

# Subplot Imaginaria
plt.subplot(1, 2, 2)
plt.plot(x_plot, u_ex.imag, 'b-', label='Exacta: $e^x \sin(t)$', alpha=0.6)
plt.scatter(x_final, u_imag_num, color='black', marker='.', s=10, label='Numérica')
plt.title(f'Parte Imaginaria en t ≈ {t_final_teorico:.4f}')
plt.xlabel('x')
plt.ylabel('Im(u)')
plt.legend()
plt.grid(True, linestyle=':')

plt.tight_layout()
plt.show()
# Out:
# <>:34: SyntaxWarning: invalid escape sequence '\c'
# <>:44: SyntaxWarning: invalid escape sequence '\s'
# <>:34: SyntaxWarning: invalid escape sequence '\c'
# <>:44: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_4841/3422032070.py:34: SyntaxWarning: invalid escape sequence '\c'
#   plt.plot(x_plot, u_ex.real, 'r-', label='Exacta: $e^x \cos(t)$', alpha=0.6)
# /tmp/ipykernel_4841/3422032070.py:44: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x_plot, u_ex.imag, 'b-', label='Exacta: $e^x \sin(t)$', alpha=0.6)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Parámetros (deben coincidir con el Fortran: m=100, N=1000, k=0.0001)
a, b = 0.0, np.pi
m = 100
N_steps = 1000
k = 0.0001
t_final = N_steps * k

# 2. Función exacta: e^{i(x+t)}
def u_exacta(x, t):
    # La forma analítica sigue siendo la misma
    return np.exp(1j * (x + t))

# 3. Cargar datos
data = np.genfromtxt('resultados.dat')

# Extraer los datos del último paso de tiempo
x_final = data[- (m + 1):, 1]
u_real_num = data[- (m + 1):, 2]
u_imag_num = data[- (m + 1):, 3]

# 4. Solución exacta
x_plot = np.linspace(a, b, 200)
u_ex = u_exacta(x_plot, t_final)

# 5. Graficar
plt.figure(figsize=(14, 5))

# Subplot Real
plt.subplot(1, 2, 1)
plt.plot(x_plot, u_ex.real, 'r-', label='Exacta: $\cos(x+t)$', alpha=0.6)
plt.scatter(x_final, u_real_num, color='black', marker='.', s=10, label='Numérica')
plt.title(f'Parte Real en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Re(u)')
plt.legend()
plt.grid(True, linestyle=':')

# Subplot Imaginaria
plt.subplot(1, 2, 2)
plt.plot(x_plot, u_ex.imag, 'b-', label='Exacta: $\sin(x+t)$', alpha=0.6)
plt.scatter(x_final, u_imag_num, color='black', marker='.', s=10, label='Numérica')
plt.title(f'Parte Imaginaria en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Im(u)')
plt.legend()
plt.grid(True, linestyle=':')

plt.tight_layout()
plt.show()

# 6. Cálculo del error máximo absoluto
u_ex_puntos = u_exacta(x_final, t_final)
error = np.abs((u_real_num + 1j * u_imag_num) - u_ex_puntos)
print(f"Error máximo absoluto en t_final: {np.max(error):.4e}")
# Out:
# <>:33: SyntaxWarning: invalid escape sequence '\c'
# <>:43: SyntaxWarning: invalid escape sequence '\s'
# <>:33: SyntaxWarning: invalid escape sequence '\c'
# <>:43: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_4841/3673184299.py:33: SyntaxWarning: invalid escape sequence '\c'
#   plt.plot(x_plot, u_ex.real, 'r-', label='Exacta: $\cos(x+t)$', alpha=0.6)
# /tmp/ipykernel_4841/3673184299.py:43: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x_plot, u_ex.imag, 'b-', label='Exacta: $\sin(x+t)$', alpha=0.6)
# Error máximo absoluto en t_final: 2.4141e+01

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Parámetros (Asegúrate de que coincidan con Fortran)
m = 100
N_steps = 1000
k = 0.0001
t_final = N_steps * k
a, b = 0.0, np.pi

# 2. Función exacta: u(x,t) = exp(x) * (cos(t) + i*sin(t))
def u_exacta(x, t):
    return np.exp(x) * (np.cos(t) + 1j * np.sin(t))

# 3. Cargar datos
try:
    data = np.genfromtxt('resultadosrampa2.dat')
except FileNotFoundError:
    print("Archivo 'resultados.dat' no encontrado. Ejecuta primero el código Fortran.")
    exit()

# 4. Extraer el último paso de tiempo (t_final)
# Buscamos los datos donde el primer valor de la fila es el t_final calculado
indices_final = np.where(np.abs(data[:, 0] - t_final) < 1e-9)[0]
x_final = data[indices_final, 1]
u_real_num = data[indices_final, 2]
u_imag_num = data[indices_final, 3]

# 5. Calcular solución exacta para referencia continua
x_plot = np.linspace(a, b, 200)
u_ex = u_exacta(x_plot, t_final)

# 6. Graficar
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Subplot Real
ax1.plot(x_plot, u_ex.real, 'r-', label='Exacta: $e^x \cos(t)$', alpha=0.6)
ax1.scatter(x_final, u_real_num, color='black', marker='.', s=15, label='Numérica')
ax1.set_title(f'Parte Real en t = {t_final:.4f}')
ax1.set_xlabel('x')
ax1.set_ylabel('Re(u)')
ax1.legend()
ax1.grid(True, linestyle='--')

# Subplot Imaginaria
ax2.plot(x_plot, u_ex.imag, 'b-', label='Exacta: $e^x \sin(t)$', alpha=0.6)
ax2.scatter(x_final, u_imag_num, color='black', marker='.', s=15, label='Numérica')
ax2.set_title(f'Parte Imaginaria en t = {t_final:.4f}')
ax2.set_xlabel('x')
ax2.set_ylabel('Im(u)')
ax2.legend()
ax2.grid(True, linestyle='--')

plt.tight_layout()
plt.show()

# 7. Verificación numérica del error
u_ex_puntos = u_exacta(x_final, t_final)
error = np.abs((u_real_num + 1j * u_imag_num) - u_ex_puntos)
print(f"Error máximo absoluto en t_final: {np.max(error):.4e}")
# Out:
# <>:37: SyntaxWarning: invalid escape sequence '\c'
# <>:46: SyntaxWarning: invalid escape sequence '\s'
# <>:37: SyntaxWarning: invalid escape sequence '\c'
# <>:46: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_4841/507250320.py:37: SyntaxWarning: invalid escape sequence '\c'
#   ax1.plot(x_plot, u_ex.real, 'r-', label='Exacta: $e^x \cos(t)$', alpha=0.6)
# /tmp/ipykernel_4841/507250320.py:46: SyntaxWarning: invalid escape sequence '\s'
#   ax2.plot(x_plot, u_ex.imag, 'b-', label='Exacta: $e^x \sin(t)$', alpha=0.6)
# Error máximo absoluto en t_final: 1.2474e+01

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Parámetros (deben coincidir con los de Fortran)
# En Fortran: a = -pi, b = pi, m = 20
a, b = -np.pi, np.pi
m = 1000
k = 0.0013
# N_steps = 769 (aunque no es estrictamente necesario para graficar el final)

# 2. Función exacta del problema de Fortran
def u_exacta(x, t):
    # En Fortran: u_exacta = exp(i*t) * cos(x)
    return np.exp(1j * t) * np.cos(x)

# 3. Cargar datos
# Usamos un try-except porque las líneas en blanco pueden causar errores en carga directa
try:
    data = np.loadtxt('resultados_2.dat')
except ValueError:
    # Si hay líneas vacías, cargamos el archivo ignorando errores de estructura
    data = np.genfromtxt('resultados.dat', comments='#')

# 4. Extraer el último paso de tiempo
# En el archivo, cada paso de tiempo tiene m+1 puntos (de 0 a m)
# El último paso corresponde a los últimos m+1 registros
num_puntos = m + 1
x_final = data[-num_puntos:, 1]
u_real_final = data[-num_puntos:, 2]
u_imag_final = data[-num_puntos:, 3]
t_final = data[-1, 0]

# Calcular solución exacta en t_final para una línea suave
x_plot = np.linspace(a, b, 200)
u_ex = u_exacta(x_plot, t_final)

# 5. Graficar
plt.figure(figsize=(12, 5))

# Subplot Parte Real
plt.subplot(1, 2, 1)
plt.plot(x_plot, u_ex.real, 'r-', label='Exacta (Real)', alpha=0.6)
plt.scatter(x_final, u_real_final, color='black', marker='x', s=30, label='Numérica (CN)')
plt.title(f'Parte Real en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Re(u)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

# Subplot Parte Imaginaria
plt.subplot(1, 2, 2)
plt.plot(x_plot, u_ex.imag, 'b-', label='Exacta (Imag)', alpha=0.6)
plt.scatter(x_final, u_imag_final, color='black', marker='x', s=30, label='Numérica (CN)')
plt.title(f'Parte Imaginaria en t = {t_final:.4f}')
plt.xlabel('x')
plt.ylabel('Im(u)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# 6. Cálculo del error en el último paso
u_num_final = u_real_final + 1j * u_imag_final
u_ex_final = u_exacta(x_final, t_final)
error = np.abs(u_num_final - u_ex_final)
print(f"Error máximo en el último paso: {np.max(error):.2e}")
# Out:
# Error máximo en el último paso: 3.91e-06
